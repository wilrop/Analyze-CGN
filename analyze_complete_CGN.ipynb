# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("data.csv")

# %%
df.columns = ["component", "language", "Length of audio files"]

flemish = df.loc[df['language'] == "vl"]
dutch = df.loc[df['language'] == "nl"]

a = df.loc[df['component'] == "comp-a"]
b = df.loc[df['component'] == "comp-b"]
c = df.loc[df['component'] == "comp-c"]
d = df.loc[df['component'] == "comp-d"]
e = df.loc[df['component'] == "comp-e"]
f = df.loc[df['component'] == "comp-f"]
g = df.loc[df['component'] == "comp-g"]
h = df.loc[df['component'] == "comp-h"]
i = df.loc[df['component'] == "comp-i"]
j = df.loc[df['component'] == "comp-j"]
k = df.loc[df['component'] == "comp-k"]
l = df.loc[df['component'] == "comp-l"]
m = df.loc[df['component'] == "comp-m"]
n = df.loc[df['component'] == "comp-n"]
o = df.loc[df['component'] == "comp-o"]

# %%
lengths = [len(a), len(b), len(c), len(d), len(e), len(f), len(g), len(h), len(i), len(j), len(k), len(l), len(m), len(n), len(o)]
print(lengths)
# Out:
# [1537, 160, 649, 581, 67, 642, 248, 265, 325, 506, 5581, 364, 16, 78, 1761]

# %%
fig, ax = plt.subplots()
df.hist(bins=30, figsize=(10,10), ax=ax)
fig.text(0.5, 0.02, 'File length', ha='center')
fig.text(0.02, 0.5, 'Amount of files', va='center', rotation='vertical')
fig.savefig("full-original-hist.pdf")

# %%
df.hist(bins=30, figsize=(10,10))
print(df.describe())
# Out:
#        Length of audio files
# count           12780.000000
# mean              224.634449
# std               271.344541
# min                 4.560562
# 25%                19.498984
# 50%               110.065750
# 75%               421.672594
# max              2106.334000

# %%
flemish.hist(bins=30,figsize=(10,10))
print(flemish.describe())
# Out:
#        Length of audio files
# count            3924.000000
# mean              276.692564
# std               277.427998
# min                 7.904000
# 25%               114.671297
# 50%               129.873437
# 75%               385.791938
# max              2106.334000

# %%
dutch.hist(bins=30)
print(dutch.describe())
# Out:
#        Length of audio files
# count            8856.000000
# mean              201.568048
# std               265.375417
# min                 4.560562
# 25%                18.446156
# 50%                21.694125
# 75%               450.403172
# max              1788.982500

# %%
a.hist(bins=30)
print(a.describe())
# Out:
#        Length of audio files
# count            1537.000000
# mean              526.177983
# std               193.298303
# min                37.052000
# 25%               418.910875
# 50%               594.001562
# 75%               610.129875
# max              1816.950000
