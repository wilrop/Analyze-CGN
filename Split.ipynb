# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("splitted_data.csv")

# %%
df = df[df['length'] <= 10]
df = df[df['length'] >= 3]
df.columns = ["component", "language", "Length of audio files"]

flemish = df.loc[df['language'] == "vl"]
df = df.loc[df['language'] == "nl"]

a = df.loc[df['component'] == "comp-a"]
b = df.loc[df['component'] == "comp-b"]
c = df.loc[df['component'] == "comp-c"]
d = df.loc[df['component'] == "comp-d"]
e = df.loc[df['component'] == "comp-e"]
f = df.loc[df['component'] == "comp-f"]
g = df.loc[df['component'] == "comp-g"]
h = df.loc[df['component'] == "comp-h"]
i = df.loc[df['component'] == "comp-i"]
j = df.loc[df['component'] == "comp-j"]
k = df.loc[df['component'] == "comp-k"]
l = df.loc[df['component'] == "comp-l"]
m = df.loc[df['component'] == "comp-m"]
n = df.loc[df['component'] == "comp-n"]
o = df.loc[df['component'] == "comp-o"]

# %%
lengths = [len(a), len(b), len(c), len(d), len(e), len(f), len(g), len(h), len(i), len(j), len(k), len(l), len(m), len(n), len(o)]
print(lengths)
# Out:
# [93653, 9249, 0, 26002, 5579, 19145, 4870, 15014, 6013, 3495, 14136, 3127, 255, 888, 23828]

# %%
fig, ax = plt.subplots()
df.hist(bins=30, ax=ax)
fig.text(0.5, 0.02, 'File length', ha='center')
fig.text(0.00, 0.5, 'Amount of files', va='center', rotation='vertical')
fig.savefig("full-splitted-hist.pdf")

# %%
df.hist(bins=30, figsize=(10,10))
print(df.describe())
# Out:
#        Length of audio files
# count          381042.000000
# mean                5.991318
# std                 1.533846
# min                 3.000000
# 25%                 4.730000
# 50%                 5.633000
# 75%                 6.986000
# max                10.000000

# %%
flemish.hist(bins=30,figsize=(10,10))
print(flemish.describe())
# Out:
#        Length of audio files
# count          155788.000000
# mean                6.134672
# std                 1.566739
# min                 3.002000
# 25%                 4.824000
# 50%                 5.820000
# 75%                 7.223000
# max                10.000000

# %%
dutch.hist(bins=30)
print(dutch.describe())
# Out:
#        Length of audio files
# count          225254.000000
# mean                5.892173
# std                 1.502703
# min                 3.000000
# 25%                 4.677000
# 50%                 5.518000
# 75%                 6.812000
# max                10.000000

# %%
a.hist(bins=30)
print(a.describe())
# Out:
#        Length of audio files
# count          155709.000000
# mean                5.833564
# std                 1.466490
# min                 3.002000
# 25%                 4.648000
# 50%                 5.455000
# 75%                 6.711000
# max                10.000000
